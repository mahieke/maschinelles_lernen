# %% [markdown]
# Beispiel für eine explorative Datenanalyse: Erdbeben der letzten 7 Tage (US Geological Survey)
# ==============================================================================================
#
# Import zweier Standardpakete für die Datenanalyse: Numpy für mehrdimensionale Arrays, Pandas für Datenanalyse in Tabellen.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Direkter Download vom USGS, Abruf des Downloaddatums, automatischer Import in Pandas-Dataframe

# %%
fileUrl = 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.csv'
eData = pd.read_csv(fileUrl)
dateDownloaded = !date
dateDownloaded
# Out:
# ['Sat Dec 12 18:23:33 CET 2015']

# %% [markdown]
# 1. Darstellung als Pandas-DataFrame
# -----------------------------------
#
# Darstellung des Datensatzes als Datensatzes als Pandas-Dataframe (Tabelle der ersten und letzten 30 Einträge, Anzahl Reihen und Spalten). Konvention: Variablen sind die Spalten, einzelne Messungen die Zeilen.

# %%
eData
# Out:
#                         time   latitude   longitude   depth   mag magType  \
# 0   2015-12-12T16:48:52.730Z  20.000999 -156.476334    0.00  2.61      md
# 1   2015-12-12T15:13:52.210Z  51.939000  178.413700  126.22  4.80      mb
# 2   2015-12-12T15:08:58.170Z -35.009800  -71.962800   42.79  5.00      mb
# 3   2015-12-12T14:46:26.780Z -10.173300  161.156100   71.07  4.80      mb
# 4   2015-12-12T14:29:46.770Z   6.742100   94.472300   17.66  4.40      mb
# 5   2015-12-12T13:42:50.800Z  18.830400  -64.347900   26.00  2.80      Md
# 6   2015-12-12T13:25:13.000Z  61.130000 -150.605700   57.50  2.70      ml
# 7   2015-12-12T12:39:57.290Z  36.281200  -97.473100    4.26  2.80   mb_lg
# 8   2015-12-12T12:14:39.100Z -12.802000  -14.678100   10.00  4.80      mb
# 9   2015-12-12T11:34:38.740Z  16.309200  -96.768400   44.77  4.50      mb
# 10  2015-12-12T11:30:56.040Z  37.488998 -118.801498    8.42  2.65      ml
# 11  2015-12-12T11:23:44.030Z  38.820499 -122.823166    2.34  2.65      md
# 12  2015-12-12T08:34:46.210Z  37.791400   21.080400   10.00  4.50     mwr
# 13  2015-12-12T07:34:20.600Z  18.989700  -67.677800   55.00  3.50      Md
# 14  2015-12-12T05:29:45.000Z  60.571600 -146.006000   18.30  2.60      ml
# 15  2015-12-12T04:44:36.850Z  38.819832 -122.823669    2.38  2.52      md
# 16  2015-12-12T02:28:56.430Z  36.277000  -97.693500    5.00  2.60   mb_lg
# 17  2015-12-12T01:36:12.030Z  36.270300  -97.562700    1.20  2.70   mb_lg
# 18  2015-12-12T01:33:18.890Z   5.635200  -77.590400   36.32  4.60      mb
# 19  2015-12-12T00:45:35.490Z -19.947500  -71.037300   15.41  4.50     mwr
# 20  2015-12-12T00:32:20.510Z  19.009400  -69.287800   24.35  4.50     mwr
# 21  2015-12-11T23:17:15.020Z -42.780500  174.182100   24.25  4.20      mb
# 22  2015-12-11T23:14:03.190Z -19.935000  -71.045400   32.75  4.00     mwr
# 23  2015-12-11T22:10:33.600Z  19.443500  -65.286300  112.00  3.30      Md
# 24  2015-12-11T22:09:39.300Z  29.534000   95.809800   24.63  4.30      mb
# 25  2015-12-11T22:05:39.520Z -47.668300   85.712300   10.00  5.00      mb
# 26  2015-12-11T22:02:46.460Z  40.329834 -124.410835    8.54  2.57      md
# 27  2015-12-11T20:56:16.300Z   9.996900  -84.101700   13.38  3.30      ml
#
#     nst    gap       dmin   rms net          id                   updated  \
# 0    34  234.0   0.668600  0.18  hv  hv61124976  2015-12-12T17:00:47.325Z
# 1   NaN   96.0   0.788000  0.56  us  us20004grd  2015-12-12T15:36:50.040Z
# 2   NaN  152.0   0.026000  1.08  us  us20004grc  2015-12-12T16:07:22.067Z
# 3   NaN   75.0   1.397000  1.00  us  us20004gr8  2015-12-12T17:17:07.511Z
# 4   NaN  145.0   2.884000  1.07  us  us20004gr3  2015-12-12T17:09:50.853Z
# 5     6  320.4   0.484192  0.10  pr  pr15346002  2015-12-12T15:39:32.022Z
# 6   NaN    NaN        NaN  0.67  ak  ak12241503  2015-12-12T13:57:29.417Z
# 7   NaN   59.0   0.468000  0.31  us  us20004gpy  2015-12-12T12:49:40.283Z
# 8   NaN   65.0   4.848000  0.77  us  us20004gpw  2015-12-12T12:33:20.924Z
# 9   NaN  178.0   2.125000  1.22  us  us20004gpr  2015-12-12T11:53:33.222Z
# 10   32  117.0   0.103200  0.04  nc  nc72567171  2015-12-12T16:51:02.060Z
# 11   41   49.0   0.009629  0.05  nc  nc72567166  2015-12-12T11:53:04.525Z
# 12  NaN   85.0   0.908000  0.97  us  us20004gp7  2015-12-12T16:37:26.955Z
# 13   16  230.4   0.817467  0.47  pr  pr15346001  2015-12-12T15:36:57.881Z
# 14  NaN    NaN        NaN  0.94  ak  ak12236580  2015-12-12T13:32:21.644Z
# 15   40   30.0   0.009461  0.05  nc  nc72567041  2015-12-12T12:47:06.220Z
# 16  NaN   92.0   0.326000  0.44  us  us20004gni  2015-12-12T04:51:08.341Z
# 17  NaN   64.0   0.412000  0.57  us  us20004gnb  2015-12-12T04:53:42.214Z
# 18  NaN  127.0   2.117000  1.53  us  us20004gnc  2015-12-12T09:35:54.470Z
# 19  NaN  156.0   0.910000  0.66  us  us20004gn3  2015-12-12T08:48:12.892Z
# 20  NaN   63.0   0.990000  0.70  us  us20004gn1  2015-12-12T02:39:06.157Z
# 21  NaN  176.0   0.598000  0.69  us  us20004gmq  2015-12-12T07:19:59.943Z
# 22  NaN  179.0   0.921000  0.76  us  us20004gmr  2015-12-12T07:16:41.848Z
# 23   11  273.6   1.128284  0.37  pr  pr15345008  2015-12-12T06:13:12.389Z
# 24  NaN  139.0   4.080000  0.37  us  us20004gm1  2015-12-12T06:12:08.046Z
# 25  NaN   65.0  22.998000  0.94  us  us20004gm0  2015-12-12T06:08:10.458Z
# 26    7  303.0   0.097060  0.06  nc  nc72566951  2015-12-12T06:05:27.511Z
# 27  NaN  134.0   0.010000  0.42  us  us20004gll  2015-12-11T21:52:51.079Z
#
#                                             place        type
# 0                      59km WNW of Kalaoa, Hawaii  earthquake
# 1           6km W of Little Sitkin Island, Alaska  earthquake
# 2                        54km NNW of Talca, Chile  earthquake
# 3           89km WNW of Kirakira, Solomon Islands  earthquake
# 4                   132km NW of Sabang, Indonesia  earthquake
# 5   53km NNE of Road Town, British Virgin Islands  earthquake
# 6                   39km WSW of Anchorage, Alaska  earthquake
# 7                       16km W of Perry, Oklahoma  earthquake
# 8                     Southern Mid-Atlantic Ridge  earthquake
# 9          10km SE of San Vicente Coatlan, Mexico  earthquake
# 10           24km SE of Mammoth Lakes, California  earthquake
# 11              7km NW of The Geysers, California  earthquake
# 12              7km SSW of Ayios Nikolaos, Greece  earthquake
# 13            82km NW of San Antonio, Puerto Rico  earthquake
# 14                    14km WNW of Cordova, Alaska  earthquake
# 15              7km NW of The Geysers, California  earthquake
# 16                   18km E of Waukomis, Oklahoma  earthquake
# 17                      24km W of Perry, Oklahoma  earthquake
# 18                    36km WSW of Nuqui, Colombia  earthquake
# 19                     98km WNW of Iquique, Chile  earthquake
# 20       10km ENE of El Valle, Dominican Republic  earthquake
# 21               58km SE of Kaikoura, New Zealand  earthquake
# 22                     99km WNW of Iquique, Chile  earthquake
# 23              126km NNE of Vieques, Puerto Rico  earthquake
# 24                        33km S of Zhamog, China  earthquake
# 25                         Southeast Indian Ridge  earthquake
# 26               30km SSW of Ferndale, California  earthquake
# 27               0km WNW of San Pablo, Costa Rica  earthquake

# %% [markdown]
# Kürzere Darstellung mit head(): nur die ersten 5 Einträge des Tabellenkopfes

# %%
eData.head()
# Out:
#                        time   latitude   longitude   depth   mag magType  nst  \
# 0  2015-12-12T16:48:52.730Z  20.000999 -156.476334    0.00  2.61      md   34
# 1  2015-12-12T15:13:52.210Z  51.939000  178.413700  126.22  4.80      mb  NaN
# 2  2015-12-12T15:08:58.170Z -35.009800  -71.962800   42.79  5.00      mb  NaN
# 3  2015-12-12T14:46:26.780Z -10.173300  161.156100   71.07  4.80      mb  NaN
# 4  2015-12-12T14:29:46.770Z   6.742100   94.472300   17.66  4.40      mb  NaN
#
#    gap    dmin   rms net          id                   updated  \
# 0  234  0.6686  0.18  hv  hv61124976  2015-12-12T17:00:47.325Z
# 1   96  0.7880  0.56  us  us20004grd  2015-12-12T15:36:50.040Z
# 2  152  0.0260  1.08  us  us20004grc  2015-12-12T16:07:22.067Z
# 3   75  1.3970  1.00  us  us20004gr8  2015-12-12T17:17:07.511Z
# 4  145  2.8840  1.07  us  us20004gr3  2015-12-12T17:09:50.853Z
#
#                                    place        type
# 0             59km WNW of Kalaoa, Hawaii  earthquake
# 1  6km W of Little Sitkin Island, Alaska  earthquake
# 2               54km NNW of Talca, Chile  earthquake
# 3  89km WNW of Kirakira, Solomon Islands  earthquake
# 4          132km NW of Sabang, Indonesia  earthquake

# %% [markdown]
# Anzahl der Reihen und Spalten mit Numpy shape().

# %%
np.shape(eData)
# Out:
# (28, 15)

# %% [markdown]
# Anzeige der einzelnen Spaltennamen mit Attribut DataFrame.columns

# %%
eData.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type'],
#       dtype='object')

# %% [markdown]
# Datentyp der einzelnen Variablen mit Attribut DataFrame.dtypes

# %%
eData.dtypes
# Out:
# time          object
# latitude     float64
# longitude    float64
# depth        float64
# mag          float64
# magType       object
# nst          float64
# gap          float64
# dmin         float64
# rms          float64
# net           object
# id            object
# updated       object
# place         object
# type          object
# dtype: object

# %% [markdown]
# 2. Aufbereitung des Datensatzes
# -------------------------------
#
# Überprüfen, ob Tabelle NaN enthält, mit DataFrame.isnull().any()

# %%
eData.isnull().any()
# Out:
# time         False
# latitude     False
# longitude    False
# depth        False
# mag          False
# magType      False
# nst           True
# gap           True
# dmin          True
# rms          False
# net          False
# id           False
# updated      False
# place        False
# type         False
# dtype: bool

# %% [markdown]
# Entfernung aller Zeilen bzw. Messungen mit NaNs durch DataFrame.dropna()

# %%
eData = eData.dropna()
eData.head()
# Out:
#                         time   latitude   longitude  depth   mag magType  nst  \
# 0   2015-12-12T16:48:52.730Z  20.000999 -156.476334   0.00  2.61      md   34
# 5   2015-12-12T13:42:50.800Z  18.830400  -64.347900  26.00  2.80      Md    6
# 10  2015-12-12T11:30:56.040Z  37.488998 -118.801498   8.42  2.65      ml   32
# 11  2015-12-12T11:23:44.030Z  38.820499 -122.823166   2.34  2.65      md   41
# 13  2015-12-12T07:34:20.600Z  18.989700  -67.677800  55.00  3.50      Md   16
#
#       gap      dmin   rms net          id                   updated  \
# 0   234.0  0.668600  0.18  hv  hv61124976  2015-12-12T17:00:47.325Z
# 5   320.4  0.484192  0.10  pr  pr15346002  2015-12-12T15:39:32.022Z
# 10  117.0  0.103200  0.04  nc  nc72567171  2015-12-12T16:51:02.060Z
# 11   49.0  0.009629  0.05  nc  nc72567166  2015-12-12T11:53:04.525Z
# 13  230.4  0.817467  0.47  pr  pr15346001  2015-12-12T15:36:57.881Z
#
#                                             place        type
# 0                      59km WNW of Kalaoa, Hawaii  earthquake
# 5   53km NNE of Road Town, British Virgin Islands  earthquake
# 10           24km SE of Mammoth Lakes, California  earthquake
# 11              7km NW of The Geysers, California  earthquake
# 13            82km NW of San Antonio, Puerto Rico  earthquake

# %%
eData.isnull().any()
# Out:
# time         False
# latitude     False
# longitude    False
# depth        False
# mag          False
# magType      False
# nst          False
# gap          False
# dmin         False
# rms          False
# net          False
# id           False
# updated      False
# place        False
# type         False
# dtype: bool

# %% [markdown]
# Überprüfen, ob Zeilen bzw. Messungen doppelt vorkommen, mit DataFrame.duplicated()

# %%
eData.duplicated().any()
# Out:
# False

# %% [markdown]
# Es kommen also keine Duplikate vor. Bei Bedarf mit *DataFrame.drop_duplicates()* entfernen.
#
# 3. Explorative Statistiken
# --------------------------
#
# Statistische Beschreibung der numerischen Variablen mit Dataframe.describe() (count: Anzahl Messungen, mean: Mittelwert, std: Standardabweichung, min: Minimum, 25%: 25-Perzentil, ...)

# %%
eData.describe()
# Out:
#         latitude   longitude       depth      mag        nst         gap  \
# count   8.000000    8.000000    8.000000  8.00000   8.000000    8.000000
# mean   29.090470 -105.330938   26.835000  2.82500  23.375000  194.675000
# std    10.482432   34.793811   38.985401  0.36789  14.889474  113.995887
# min    18.830400 -156.476334    0.000000  2.52000   6.000000   30.000000
# 25%    19.330050 -123.220461    2.370000  2.60000  10.000000  100.000000
# 50%    28.744999 -120.812332    8.480000  2.65000  24.000000  232.200000
# 75%    38.819999  -67.079925   33.250000  2.92500  35.500000  280.950000
# max    40.329834  -64.347900  112.000000  3.50000  41.000000  320.400000
#
#            dmin       rms
# count  8.000000  8.000000
# mean   0.414737  0.165000
# std    0.425432  0.165874
# min    0.009461  0.040000
# 25%    0.075202  0.050000
# 50%    0.293696  0.080000
# 75%    0.705817  0.227500
# max    1.128284  0.470000

# %% [markdown]
# Streumatrix für alle numerischen Variablen mit Pandas *scattermatrix()*:

# %%
pd.scatter_matrix(eData, figsize=(14,14), marker='o');

# %% [markdown]
# 4. Analyse von Untermengen
# --------------------------
#
# Zugriff auf die Variable 'Lat' (latitude):

# %%
eData['Lat']

# %% [markdown]
# Welche Erdbeben fanden oberhalb einer geographischen Breite von 40 Grad statt?

# %%
eData['Lat'] > 40.0

# %% [markdown]
# Gab es überhaupt Erdbeben oberhalb 50 Grad Breite?

# %%
(eData['Lat'] > 40.0).any()

# %% [markdown]
# Gab es also. Haben alle verzeichneten Erdbeben eine Breite größer als 18 Grad?

# %%
(eData['Lat'] > 18.0).all()

# %% [markdown]
# Es sind also auch Erdbeben unterhalb von 18 Grad verzeichnet.
#
# Alle unterschiedlichen Werte der kategorischen Variable 'Version' mit Dataframe['Variablenname'].*unique()*

# %%
eData['Version'].unique()

# %% [markdown]
# Häufigkeit der verschiedenen Kategorien in 'Version' mit Dataframe['Variablenname'].*value_counts()*:

# %%
eData['Version'].value_counts()

# %% [markdown]
# Häufigkeit von Wertepaaren der beiden kategorischen Variablen 'Version' und 'Src' mit Pandas *crosstab()*:

# %%
pd.crosstab(eData['Src'], eData['Version'])

# %% [markdown]
# Darstellung der Häufigkeitsverteilung der Erdbebenstärken für die verschiedenen Quellen mit einer Kastengraphik durch Pandas *boxplot()*:

# %%
from pandas.tools.plotting import boxplot
boxplot(eData, column='Magnitude', by='Src');
