# %% [markdown]
# ## Aufgabe 1 Perzeptron

# %%
# %matplotlib inline
import util
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
variance = 0.04
data = 400
pos = [0,0]
pos_vec = [0.4, 0.5]
(d1, l1), (d2, l2) = util.create_isotropic_gaussian_twindataset(pos, data, variance, pos_vec)
d1 = pd.DataFrame(d1, index=l1, columns=['x','y'])
d2 = pd.DataFrame(d2, index=l2, columns=['x','y'])

ax = d1.plot(kind='scatter', x='x', y='y', figsize=(9,9), color='DarkGreen', label='Data 1 ({})'.format(l1[0]))
d2.plot(kind='scatter', x='x', y='y', figsize=(9,9), color='Yellow', label='Data 2 ({})'.format(l2[0]), ax=ax)

# %%
# Out:
# ([array([ 0.05933456,  0.        ,  0.17800369,  0.        ,  0.05933456,
#           0.4746765 ,  0.59334562,  0.83068387,  1.00868756,  0.77134931,
#           1.898706  ,  2.13604424,  1.30536037,  1.78003687,  1.78003687,
#           1.898706  ,  1.54269862,  1.48336406,  1.54269862,  1.48336406,
#           0.83068387,  0.53401106,  0.59334562,  0.35600737,  0.29667281,
#           0.23733825,  0.        ,  0.        ,  0.05933456,  0.        ]),
#   array([ 0.        ,  0.        ,  0.        ,  0.05933456,  0.05933456,
#           0.11866912,  0.23733825,  0.23733825,  0.53401106,  0.53401106,
#           0.41534194,  0.949353  ,  1.72070231,  1.4240295 ,  1.36469493,
#           2.07670968,  2.13604424,  1.54269862,  1.898706  ,  2.13604424,
#           1.06802212,  1.48336406,  1.06802212,  0.83068387,  0.41534194,
#           0.59334562,  0.41534194,  0.23733825,  0.11866912,  0.05933456])],
#  array([ -2.11207317e-01,  -1.69073359e-01,  -1.26939400e-01,
# ...
